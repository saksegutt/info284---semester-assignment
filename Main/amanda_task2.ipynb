# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
print(os.listdir("art"))

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
import matplotlib.pyplot as plt
import numpy as np


train_ds = tf.keras.utils.image_dataset_from_directory(
    "art/",
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "art/",
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

# Load EfficientNetB0 model without pre-trained weights
base_model = EfficientNetB0(weights=None, include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
base_model.trainable = False

# Create the model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=2
)

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ['.DS_Store', 'real', 'ai']
# Found 962 files belonging to 2 classes.
# Using 770 files for training.
# Found 962 files belonging to 2 classes.
# Using 192 files for validation.
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,410,661 (16.83 MB)
#  Trainable params: 361,090 (1.38 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/2
# 2026-04-13 15:13:52.506205: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:52.626100: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:52.633496: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: profile 'ICC Profile': 'CMYK': invalid ICC profile color space
# 2026-04-13 15:13:52.647093: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:52.869685: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:53.174717: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:53.189824: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:53.563180: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  1/25 ━━━━━━━━━━━━━━━━━━━━ 2:40 7s/step - accuracy: 0.4062 - loss: 0.6931
# 2026-04-13 15:13:53.889897: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:54.493568: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:54.619658: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  2/25 ━━━━━━━━━━━━━━━━━━━━ 21s 924ms/step - accuracy: 0.4219 - loss: 0.6932
# 2026-04-13 15:13:54.698612: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:54.952853: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.028165: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.154946: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.263661: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.524154: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.684896: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.699657: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.722594: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  3/25 ━━━━━━━━━━━━━━━━━━━━ 20s 947ms/step - accuracy: 0.4271 - loss: 0.6933
# 2026-04-13 15:13:55.819257: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:55.958467: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  5/25 ━━━━━━━━━━━━━━━━━━━━ 18s 923ms/step - accuracy: 0.4322 - loss: 0.6933
# 2026-04-13 15:13:57.538258: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:57.679867: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:57.807930: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  6/25 ━━━━━━━━━━━━━━━━━━━━ 16s 890ms/step - accuracy: 0.4418 - loss: 0.6933
# 2026-04-13 15:13:58.292304: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:58.303300: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  7/25 ━━━━━━━━━━━━━━━━━━━━ 15s 876ms/step - accuracy: 0.4494 - loss: 0.6932
# 2026-04-13 15:13:59.171070: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:13:59.207668: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  8/25 ━━━━━━━━━━━━━━━━━━━━ 14s 857ms/step - accuracy: 0.4548 - loss: 0.6932
# 2026-04-13 15:13:59.844483: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 10/25 ━━━━━━━━━━━━━━━━━━━━ 12s 849ms/step - accuracy: 0.4641 - loss: 0.6931
# 2026-04-13 15:14:01.510516: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14
W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  6/25 ━━━━━━━━━━━━━━━━━━━━ 14s 786ms/step - accuracy: 0.5859 - loss: 0.6853
# 2026-04-13 15:14:22.773114: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:22.842176: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  7/25 ━━━━━━━━━━━━━━━━━━━━ 14s 782ms/step - accuracy: 0.5877 - loss: 0.6853
# 2026-04-13 15:14:23.536721: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:23.838319: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:23.859991: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:23.930771: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  8/25 ━━━━━━━━━━━━━━━━━━━━ 13s 800ms/step - accuracy: 0.5875 - loss: 0.6854
# 2026-04-13 15:14:24.654549: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:24.675848: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:24.728628: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
#  9/25 ━━━━━━━━━━━━━━━━━━━━ 12s 809ms/step - accuracy: 0.5870 - loss: 0.6856
# 2026-04-13 15:14:25.309679: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:25.390807: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 10/25 ━━━━━━━━━━━━━━━━━━━━ 12s 815ms/step - accuracy: 0.5861 - loss: 0.6858
# 2026-04-13 15:14:26.267560: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:26.456545: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 11/25 ━━━━━━━━━━━━━━━━━━━━ 11s 825ms/step - accuracy: 0.5848 - loss: 0.6860
# 2026-04-13 15:14:26.904722: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:26.999894: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:27.090584: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 12/25 ━━━━━━━━━━━━━━━━━━━━ 10s 829ms/step - accuracy: 0.5833 - loss: 0.6862
# 2026-04-13 15:14:27.969633: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:27.977255: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:28.014175: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:28.070541: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:28.219095: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 9s 831ms/step - accuracy: 0.5823 - loss: 0.6863
# 2026-04-13 15:14:28.806338: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:28.808181: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:28.860642: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:28.928526: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 9s 834ms/step - accuracy: 0.5818 - loss: 0.6864
# 2026-04-13 15:14:29.851129: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 8s 836ms/step - accuracy: 0.5811 - loss: 0.6865
# 2026-04-13 15:14:30.538518: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:30.540001: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:30.581197: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 7s 830ms/step - accuracy: 0.5805 - loss: 0.6865
# 2026-04-13 15:14:31.307504: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:31.363523: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:31.419732: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: profile 'ICC Profile': 1000000h: invalid rendering intent
# 2026-04-13 15:14:31.430899: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 6s 830ms/step - accuracy: 0.5798 - loss: 0.6866
# 2026-04-13 15:14:32.113099: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:32.117864: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:32.254454: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 5s 823ms/step - accuracy: 0.5790 - loss: 0.6867
# 2026-04-13 15:14:32.897293: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:32.916394: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:32.949777: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:33.050095: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.5732 - loss: 0.6872
# 2026-04-13 15:14:36.453914: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:36.813883: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:36.971078: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.038283: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.044968: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.355139: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.701493: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.731759: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.736151: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.755343: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.783772: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 2026-04-13 15:14:37.895877: W tensorflow/core/lib/png/png_io.cc:95] PNG warning: iCCP: known incorrect sRGB profile
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 918ms/step - accuracy: 0.5519 - loss: 0.6891 - val_accuracy: 0.5573 - val_loss: 0.6879
